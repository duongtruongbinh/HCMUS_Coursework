# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127229_europe_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0         2775634.0          1391086.0        1384548.0   11.602368
# 1         2811666.0          1407212.0        1404454.0   10.240000
# 2         2837849.0          1418585.0        1419264.0   10.285000
# 3         2854191.0          1425363.0        1428828.0   10.343000
# 4         2866376.0          1430495.0        1435881.0   10.517000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.088641                        9.0                   26.94914
# 1   11.325000                        9.0                   21.56278
# 2   10.785000                        9.0                   20.78154
# 3    8.480000                        9.0                   20.15067
# 4    8.308000                        9.0                   19.74566
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                      9.979687                             9.062241
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1520, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.520000e+03       1.520000e+03     1.520000e+03  1520.000000
# mean       1.385425e+07       7.136818e+06     6.717430e+06    11.602368
# std        2.060535e+07       1.062078e+07     9.988727e+06     2.569355
# min        2.224100e+04       1.121100e+04     1.103000e+04     5.900000
# 25%        2.011366e+06       1.023291e+06     9.939572e+05     9.800000
# 50%        5.303756e+06       2.686208e+06     2.607268e+06    11.300000
# 75%        1.045922e+07       5.398385e+06     5.066896e+06    12.700000
# max        8.407981e+07       4.259320e+07     4.148661e+07    26.297000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1520.000000                1520.000000                1520.000000
# mean     10.088641                  10.231975                  26.949140
# std       2.317468                   1.092346                   5.720223
# ...

# %%
df_copy['Unemployment(%)'].describe()
# Out:
# count    1520.000000
# mean        9.450200
# std         5.410381
# min         0.600000
# 25%         6.110000
# 50%         9.450200
# 75%         9.804500
# max        38.800000
# Name: Unemployment(%), dtype: float64

# %% [markdown]
# **TODO**: Give your obervation here
#
#
# 1. **Population Statistics:**
#     - The total population of countries in the dataset ranges from 22.2 thousand to 84.07 million, with an average of 13.85 million.
#     - On average, the female population is higher than the male population (7.36 million on average compared to 6.49 million).
#
# 2. **Demographic Rates:**
#    - The average birth rate is relatively low (11.6), with about 75% of the rates falling below 12.7.
#    - The average death rate is high (10.08), with the highest reaching 21.7.
#    - Birth rates are generally higher than death rates (averaging 11.60 and 10.08).
#    - Compulsory education durations vary among countries (ranging from 8 to 13 years) with an average of 10.21 years, primarily between 9 and 11 years (standard deviation around 1 year).
#
# 3. **Employment Statistics:**
#    - Employment in the industry and agriculture sectors varies significantly, with averages of 26.95% and 9.98%, respectively.
#    - However, employment in the agriculture sector exhibits significant fluctuations over time (standard deviation approximately 8.7%).
#    - On average, the female employment in agriculture and industry is different, with averages of 9.06% and 16.09%, respectively.
#    - Female employment in agriculture also shows temporal variations (standard deviation around 10.01%).
#    - The average unemployment rate is 9.45%, with a standard deviation of 5.4%, ranging from 0.6% to 38.8%.
#
# 4. **Economic Indicators:**
#    - GDP varies significantly over time, with an average of 382.2 billion USD and a standard deviation of 670 billion USD (ranging from 528 million USD to 4.26 trillion USD).
#    - Net income from abroad exhibits a wide range, with an average of approximately -152.32 million USD, indicating that some countries have net income deficits. The standard deviation is relatively high.
#
# 5. **Energy Consumption:**
#    - Electric Power Consumption per capita shows significant variations over time, with an average of 6,828 kWh and a standard deviation of 5,256 kWh (ranging from 418 kWh to 54,799 kWh).
#    - Renewable Energy Consumption among countries also exhibits significant variations over time, with an average of 18% and a standard deviation of 15% (ranging from 0% to 82.7%).
#    - Fossil Fuel Consumption in countries remains high (average of 75% and up to 100%).
#
# 6. **Life Expectancy:**
#    - Male life expectancy is lower on average compared to female life expectancy (73.26 and 79.83).
#    - The variation in life expectancy between males and females is not significant (standard deviation of 4.9 and 3.3).
#
# 7. **Education Enrollment:**
#    - School enrollment in primary and tertiary education shows distinct differences, with averages of 101.31 and 50.59, respectively.
#    - Enrollment in tertiary education exhibits more variability compared to primary education (standard deviation of 20.08 compared to 5.46).
#    - The primary completion rate of countries has an average value of 97.57, mostly below 98.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# Based on the correlation matrix, we can observe several features that are correlated with each other. We will ignore the correlations involving features such as `Total Population`, `Female Population`, and `Male Population` (as this is expected).
#
# - `Female Employment in Agriculture(%)` and `Employment in Agriculture(%)`, as well as `Female Employment in Industry(%)` and `Employment in Industry(%)`, show a high positive correlation with each other but do not correlate significantly with `Female Population`. This may imply that the number of women in the population does not significantly affect the employment rates in agriculture and industry.
#
# - `GDP in USD` and `Agriculture value added(in USD)` show a high positive correlation with `Total Population` (and, of course, with `Female Population` and `Male Population`). This means that countries with larger populations tend to have higher GDP and agriculture value added, which can be explained by several factors:
#     - A larger population leads to a larger consumer market, increasing demand for goods and services, including agriculture.
#     - A larger population provides a larger labor force, which helps countries develop their economies, including agriculture.
#     - A larger population also leads to higher potential for innovation and creativity, contributing to economic growth in various sectors.
#
#     However, there are exceptions (some countries with high GDP but relatively small populations, etc.). Using this correlation can help nations make more informed decisions about economic and population policies.
#
# - `GDP in USD` and `Agriculture value added(in USD)` show a positive correlation with each other (because they are both correlated with `Total Population`), indicating that agriculture has a significant impact and plays an essential role in creating economic value.
#
# - `Fossil Fuel Consumption (%)` has a negative correlation with `Electric Power Consumption(kWH per capita)` and `Renewable Energy Consumption (%)`. This means that countries that consume more fossil fuels tend to consume less electricity per capita and less renewable energy. This is an interesting relationship because fossil fuels are harmful to the environment, while electricity and renewable energy sources are cleaner and more sustainable.
#
# - `Male life expectancy` and `Female life expectancy` have a high positive correlation because both are influenced by similar factors, such as healthcare conditions, quality of life, and socioeconomic conditions.

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# Get the top 10 contries with the largest population
largest_population_lst = cleaned_df.groupby('Country')['Total Population'].max().sort_values(ascending=False).head(10).index.tolist()
largest_population_df = cleaned_df[cleaned_df['Country'].isin(largest_population_lst)]

# %%
# YOUR CODE HERE
largest_copy = largest_population_df.copy()

# Exclude the categorical features from the matrix
largest_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(largest_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**

# %% [markdown]
# - The overall correlation matrix for the top 10 most populous countries is higher and more distinct correlations (such as the correlations between features `Female Employment in Industry(%)`, `Employment in Industry(%)`, `Employment in Agriculture`, `Female Employment in Agriculture`...). This may be because this is a correlation matrix specific to these 10 countries, so the relationships between them are more accurately reflected.
#
# - Some features have shifted from positive correlations to negative correlations (and vice versa)(`Female Employment in Industry(%)` and `Total Population`...)
# - Some features show significant changes:
#     - `GDP in USD` and `Employment in Agriculture` have a higher negative correlation, meaning that countries with a higher GDP tend to have a lower employment rate in agriculture. This can be explained by:
#         - Economic development is often accompanied by a diversification of occupations, so the percentage of the workforce in agriculture decreases, and workers move to other sectors such as industry and services.
#         - Technological advancements increase labor productivity, requiring fewer workers in agriculture.
#         - Economic development leads to urbanization, where there are more job opportunities in industries and services.
#     - `Electric Power Consumption(kWH per capita)` has a higher negative correlation with `Employment in Agriculture` (as well as `Female Employment in Agriculture`), meaning that countries with higher electricity consumption tend to have a lower employment rate in agriculture. This can be explained by several reasons:
#         - The development of other sectors, such as industry and services, demands more energy for operations.
#         - Highly populous countries are modernizing agriculture, using technology to increase productivity. Electricity is used to improve production processes, from automated irrigation to the use of machinery and high-tech equipment, reducing labor and increasing energy consumption.
#     - Both `Male life expectancy` and `Female life expectancy` have a high negative correlation with `Employment in Agriculture`. Similar to the reasons mentioned above, the decrease in the agricultural labor force is due to economic development. As a result, technology, education, healthcare, and overall quality of life have improved, leading to increased life expectancy.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
smallest_population_lst = cleaned_df.groupby('Country')['Total Population'].max().sort_values(ascending=True).head(10).index.tolist()
smallest_population_df = cleaned_df[cleaned_df['Country'].isin(smallest_population_lst)]

# %%
# YOUR CODE HERE
smallest_copy = smallest_population_df.copy()

# Exclude the categorical features from the matrix
smallest_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(smallest_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?

# %% [markdown]
# In the correlation matrix of the 10 least populous countries, there are distinct differences in the relationships between features.
# - Four features related to employment, such as `Employment in Industry`, `Female Employment in Industry`, etc., show a positive correlation with each other and with `Total Population` (as well as `Male Population` and `Female Population`). This is understandable because as the population increases, the demand for jobs increases, leading to more employment opportunities. However, `Unemployment(%)` shows a higher positive correlation with `Total Population` compared to the other four features. In sparsely populated countries, the labor market is limited, leading to high competition for job positions. When the population increases, it can exceed the economy's capacity to create jobs, resulting in a higher unemployment rate.
#
# - `GDP in USD` and `Agriculture value added (in USD)` change from a high positive correlation to a low negative correlation with `Total Population`. This may be due to the policies and political decisions of sparsely populated countries, which may have taken measures to diversify their economies and reduce their dependence on agriculture.
#
# - `Fossil Fuel Consumption (%)` changes from a positive correlation to a negative correlation with `Total Population`. This indicates that in less populous countries, the consumption of fossil fuels has decreased significantly despite an increase in population. These countries are promoting the use of clean and renewable energy sources, such as solar and wind energy.
#
# - `Male life expectancy` and `Female life expectancy` also change from a positive correlation to a high negative correlation with `Total Population` in the less populous countries in Europe. This may be due to factors such as the quality of life and better healthcare infrastructure.

# %% [markdown]
# It is possible to drop features that have less impact on the outcome
# - Benefits:
#
#     - Reduced data size and complexity
#     - Improved accuracy and generalization
#     - Reduced noise and multicollinearity
#     - Faster analysis and training
#     - Better model transparency and simplicity
#     - Time and resource savings
# - Examples:
#
#     - Market data analysts drop features that are not strongly correlated with the target variable, such as social media users or website likes.
#     - Data engineers drop features that contain missing or erroneous values.
#     - Machine learning engineers drop features that are unimportant or redundant.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate        Country
# 0        16.568641        Albania
# 17       14.907957        Iceland
# 10       14.679010  Faroe Islands
# 18       14.629010        Ireland
# 26       14.522747        Moldova

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate   Country
# 38       14.492727   Ukraine
# 5        14.202333  Bulgaria
# 20       14.099701    Latvia
# 16       13.468122   Hungary
# 2        12.970675   Belarus

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here

# %% [markdown]
# Considering the birth rate of all countries in Europe based on the charts above and below, we can make the following observations:
#
# - The country with the highest average birth rate is Albania at 16.57%.
# - Most countries have an average birth rate ranging from 10% to 12%. This indicates a relatively stable level of fertility across Europe.
# - European countries generally have low average birth rates, primarily below 15%. This highlights that many European nations are facing issues with low birth rates, which could lead to population decline in the future if not addressed.
# - Some countries have even lower average birth rates, such as Bulgaria (9.88%), Spain (9.80%), Greece (9.61%), and Germany (9.46%), indicating lower fertility levels in the southeastern and southwestern regions of the continent compared to central Europe.
# - Ireland, Iceland, and the Faroe Islands all have high average birth rates, ranging from 14.62% to 14.91%, demonstrating high fertility levels in the Northern European region.

# %%
# Plot birthrate and distribution of birthrate for all countries in Europe
plt.figure(figsize=(10, 7))

plt.subplot(121)
sns.distplot(avg_birthrate_df["Avg.Birth Rate"], color="blue")
plt.title("Distribution of Birth Rate")

plt.subplot(122)
sns.barplot(x=avg_birthrate_df["Avg.Birth Rate"], y=avg_birthrate_df["Country"], color="skyblue")
plt.title("Average Birth Rate for each Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# Considering the death rate of all countries in Europe based on the data provided, here are some reasonable and insightful observations:
#
# - The country with the highest average death rate in the list is Ukraine, at approximately 14.49%. This could be attributed to various factors, including the impact of the COVID-19 pandemic and the ongoing conflict between Ukraine and Russia. These factors may have significantly contributed to the elevated death rate in Ukraine.
#
# - Many European countries have average death rates ranging from 8% to 13%. This range indicates a considerable variance in mortality rates across the continent, likely due to differences in healthcare systems, living conditions, and demographic factors.
#
# - Some countries have notably lower death rates, such as Albania (6.77%), Liechtenstein (6.75%), and Iceland (6.64%). These lower death rates may suggest that these countries have relatively better healthcare systems and overall health conditions for their populations.
#
# - There appears to be a correlation between death rates and birth rates in some cases. Countries with higher birth rates tend to have lower death rates, and vice versa. This could be indicative of the complex relationship between demographic factors and health outcomes in different countries.
#
# - The five countries with the highest average death rates are Ukraine, Bulgaria, Latvia, Hungary, and Belarus. The elevated death rates in these countries could be attributed to a combination of factors, including the impact of the COVID-19 pandemic, healthcare infrastructure, and socioeconomic conditions.
#
# Overall, the variations in average death rates among European countries reflect the diverse health and socioeconomic landscapes across the continent. These observations provide insights into the challenges and opportunities for healthcare and public health efforts in Europe.

# %%
# Plot birthrate and distribution of deadthrate for all countries in Europe
plt.figure(figsize=(10, 7))

plt.subplot(121)
sns.distplot(avg_deathrate_df["Avg.Death Rate"], color="blue")
plt.title("Distribution of Death Rate")

plt.subplot(122)
sns.barplot(x=avg_deathrate_df["Avg.Death Rate"], y=avg_deathrate_df["Country"], color="skyblue")
plt.title("Average Death Rate for each Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **A possible question is:** What is the current gender population structure in European countries?
#
# **Answering this question will** help us understand the gender population structure to formulate appropriate policies on population, labor force, and gender equality. It will also aid in devising solutions to balance gender disparities in the population through reproductive measures, education...
#
# **How we answer this question**:
# - Since the dataset spans from 1985 to 2022, we will analyze the population data from the year 2022 to assess the current population structure in European countries.
# - Based on the male and female populations from the dataset, we will calculate the percentage of males and females for each European country and for the entire European continent.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
population_2022 = cleaned_df[cleaned_df['Year'] == 2022][['Total Population','Male Population','Female Population','Country']]
population_2022['Male Population Ratio (%)'] = population_2022['Male Population'] / population_2022['Total Population'] * 100
population_2022['Female Population Ratio (%)'] = population_2022['Female Population'] / population_2022['Total Population'] * 100

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# Tính tỉ lệ nam và nữ cho tổng dân số cả châu Âu
total_male_population = population_2022['Male Population'].sum()
total_female_population = population_2022['Female Population'].sum()
total_population = total_male_population + total_female_population
male_ratio = (total_male_population / total_population) * 100
female_ratio = (total_female_population / total_population) * 100

# Vẽ biểu đồ tròn
labels = ['Male','Female']
ratio = [male_ratio, female_ratio]
colors = ['blue', 'pink']
explode = (0.05, 0)  # Tách phần "Nam" ra để làm nổi bật

plt.figure(figsize=(10, 7))
plt.subplot(1, 2, 1)  
plt.barh(population_2022['Country'], population_2022['Male Population Ratio (%)'], label= 'Male Population Ratio (%)', color='blue')
plt.barh(population_2022['Country'], population_2022['Female Population Ratio (%)'], label='Female Population Ratio (%)', left=population_2022['Male Population Ratio (%)'], color='pink')
plt.axvline(x=50, color='black', linestyle='--', label='50%')
plt.ylabel('Country')
plt.xlabel('Ratio (%)')
plt.legend()

plt.subplot(1, 2, 2)
plt.pie(ratio, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=explode)
plt.axis('equal')

plt.suptitle('Gender Population Structure in Europe in 2022', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the above charts, we can make some comments and answer questions about the population structure by sex in Europe as follows:
#
# - **Overall**: The gender population structure in European countries shows relatively balanced distribution. This indicates gender equality within the population, with minimal discrepancies between male and female ratios.
#
# - The gender disparities in the population of European countries are not significant. On average, the male-to-female ratio in the total population is close to 50%, with some countries having slightly higher male or female ratios. Additionally, several European countries exhibit the least gender disparities, with the closest male-to-female ratios (e.g., United Kingdom, Switzerland). This reflects a good gender balance in these nations.
#
# - Some countries display more substantial gender disparities. In Ukraine, the gender population ratio is notable, with males accounting for 54.08% and females 45.92% of the total population. Iceland, on the other hand, shows a higher male ratio of 51.26% compared to females at 48.74%. Despite these differences, gender disparities in these nations are not excessively significant
#
# - Calculated across the entire European continent, the female population slightly outweighs the male population (51.3% versus 48.7%).
#
# These observations can help shape population, education, and labor policies that align with the actual gender population structure in each European country. Such policies can aim to ensure gender equality, balance gender disparities within the population, cater to the labor force's needs, and optimize human resources for economic and social development.

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **A possible question is:** What is the current unemployment rate in European countries today?
#
# **Answering this question will** help us understand the current unemployment situation in European countries, allowing us to propose appropriate solutions to mitigate unemployment, ensuring economic and social stability.
#
# **How we answer this question**: By calculating the average unemployment rate of European countries based on data provided across all years and the average unemployment rate for the entire continent over the years to analyze and provide insights.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
avg_unemployment_df = cleaned_df.groupby('Country')['Unemployment(%)'].mean().sort_values(ascending=False)
avg_unemployment_df = avg_unemployment_df.reset_index()
# unemployment rate in Europe by year
unemployment_df = cleaned_df.groupby('Year')['Unemployment(%)'].mean()
unemployment_df = unemployment_df.reset_index().sort_values('Year', ascending=True)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(10, 7))

plt.subplot(121)
sns.distplot(avg_unemployment_df["Unemployment(%)"], color="purple")
plt.title("Distribution of Unemployment Rate")

plt.subplot(122)
sns.barplot(x=avg_unemployment_df["Unemployment(%)"], y=avg_unemployment_df["Country"], color="blue")
plt.title("Average Unemployment Rate for each Country")
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(7, 5))
sns.lineplot(data=unemployment_df, x='Year', y='Unemployment(%)', marker='o', color='blue', label='Unemployment Rate')
ax.set_title('Unemployment Rate in Europe Over the Years', fontsize=16)
ax.set_xlabel('Year')
ax.set_ylabel('Unemployment Rate (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the charts above, we can make the following observations to answer the question about the unemployment rate in Europe:
#
# - Currently, we can see that some European countries are grappling with relatively high unemployment rates. Macedonia, FYR leads with the highest unemployment rate at 26.28%, while Bosnia and Herzegovina also reports a significant unemployment rate, reaching 21.48%. Countries like Spain, Albania, and Greece also record unemployment rates above 10%. However, it's worth noting that there are countries with lower-than-average unemployment rates, such as Iceland and Switzerland, with unemployment rates below 5%.
# - There is an overall trend of decreasing average unemployment rates in Europe in recent years. From a level of 9.45% in 1985, the average unemployment rate in Europe has dropped to 6.50% in 2022
# - Unemployment situations in European countries are influenced by a myriad of factors, including economic, political, and social conditions. The global financial crisis in 2008 and the COVID-19 pandemic are two prominent examples that led to a substantial increase in unemployment. However, subsequent economic recovery efforts have significantly reduced unemployment rates.

# %% [markdown]
# ## Making your own question 03?

# %% [markdown]
# **YOUR ANSWER HERE**
# **A possible question is:** What is the economic situation in terms of average GDP of the countries in Europe today?
#
# **Answering this question will** allow us to gain insights into the current economic status and make informed assessments of the overall economic health and development of the countries in Europe.
#
# **How we answer this question**: We will calculate the average GDP for countries across all the years and use this data to analyze and make observations regarding the economic conditions in these countries.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
avg_gdp_df = cleaned_df.groupby('Country')['GDP in USD'].mean().sort_values(ascending=False)
avg_gdp_df = avg_gdp_df.reset_index()
# Get the 10 countries with the highest GDP
top_10_gdp = avg_gdp_df.head(10)
# GDP in Europe by year
gdp_df = cleaned_df.groupby('Year')['GDP in USD'].mean()
gdp_df = gdp_df.reset_index().sort_values('Year', ascending=True)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.distplot(avg_gdp_df["GDP in USD"], color="purple", ax=axes[0])
axes[0].set_title("Distribution of GDP")

sns.barplot(x="GDP in USD", y="Country", data=top_10_gdp, color="blue", ax=axes[1])
axes[1].set_title("Top 10 Average GDP for Each Country")
axes[1].set_xlabel("Average GDP (in USD)")
axes[1].set_ylabel("Country")

sns.barplot(x="GDP in USD", y="Country", data=avg_gdp_df[10:], color="blue", ax=axes[2])
axes[2].set_title("Average GDP for other Country in Europe")
axes[2].set_xlabel("Average GDP (in USD)")
axes[2].set_ylabel("Country")

plt.tight_layout()
plt.show()

# %%
# Plot GDP in Europe over the years
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(7, 5))
sns.lineplot(data=gdp_df, x='Year', y='GDP in USD', marker='o', color='blue', label='GDP')
ax.set_title('GDP in Europe Over the Years', fontsize=16)
ax.set_xlabel('Year')
ax.set_ylabel('GDP in USD')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the provided data, we can make the following observations to answer the question:
# - The distribution of GDP across European countries varies significantly, with some countries having much higher GDP values than others. For instance, Germany, the United Kingdom, France, and Italy are among the top European countries with the highest GDP, each having GDP values in the trillions of USD.
# - Germany is the leading country in terms of GDP, with a GDP of approximately 2.74 trillion USD. The United Kingdom, France, and Italy also have GDP values exceeding 1.5 trillion USD, making them significant economic powerhouses in Europe.
# - When looking at the historical trend of GDP in Europe, there has been a general increase in GDP values over the years, with occasional fluctuations. The European GDP increased from around 243 billion USD in 1985 to approximately 5.75 trillion USD in 2022. This suggests overall economic growth in the continent.
# - As of 2022, the total GDP of Europe stands at approximately 5.75 trillion USD, indicating a robust and substantial economy.
# - While some European countries, such as Germany and the United Kingdom, contribute significantly to the overall GDP of the continent, there is a wide range of GDP values among European nations. Some countries have relatively lower GDP values compared to the top performers. Europe showcases a diverse economic landscape with both developed and emerging economies, each contributing differently to the overall GDP of the continent.
# - Economic growth has not been uniform, and the continent experienced fluctuations, likely influenced by events such as the global financial crisis in 2008 and the COVID-19 pandemic.

# %% [markdown]
# ## Making your own question 04?

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **A possible question is:** How has the economic growth of the countries with the highest GDP in Europe evolved over the years in terms of 'GDP in USD'?
#
# **Answering this question will** help us understand the historical economic performance of the leading economies in Europe and provide insights into their economic growth trends, allowing us to make informed assessments of their economic health and development. This information can be used to devise appropriate economic policies and strategies to ensure sustainable economic growth.
#
# **How we answer this question**: We will focus on top 5 countries with the highest GDP values at present (2022) and track their 'GDP in USD' over multiple years to observe their economic growth patterns and identify any significant trends or changes.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
# Get the 10 countries with the highest GDP in 2022
top_5_gdp = cleaned_df[cleaned_df['Year'] == 2022].sort_values('GDP in USD', ascending=False)['Country'].head(5).tolist()
# Track the GDP of the top 10 countries over the years
top_5_gdp_df = cleaned_df[cleaned_df['Country'].isin(top_5_gdp)]
# top_5_gdp_df[['Country', 'Year', 'GDP in USD']].sort_values(['Country', 'Year'], ascending=True).to_csv('test.csv', index=False)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(10, 5))
for country in top_5_gdp:
    country_data = top_5_gdp_df[top_5_gdp_df['Country'] == country]
    plt.plot(country_data['Year'], country_data['GDP in USD'], label=country)

plt.title('GDP Growth of the Top 5 Countries in Europe Over the Years')
plt.xlabel('Year')
plt.ylabel('GDP in USD')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - These countries have experienced consistent economic growth from 1985 to 2022, with varying rates of growth.
#
#     - France demonstrated steady economic growth throughout the years, with occasional fluctuations.
#     - Germany exhibited consistent and robust economic growth, maintaining its position as one of the top economies in Europe.
#     - Italy faced periods of economic challenges but rebounded in the 2000s, with a relatively stable growth trajectory.
#     - Spain experienced significant economic growth, particularly in the early 2000s, but had to overcome the challenges of the 2008 financial crisis.
#     - The United Kingdom showcased continuous growth, with occasional fluctuations, and remained one of the leading economies in Europe.
# - Impact of Global Events:
#
#     - The financial crisis of 2008 had a noticeable impact on some of these countries, causing economic fluctuations.
#     - The economic consequences of the COVID-19 pandemic in 2020 were also evident, but the economies rebounded in 2021 and 2022.
#
# These nations are intricately linked in their economic progress, with their GDPs frequently exhibiting mutual trends. They have exemplified remarkable resilience and adaptability when confronted with economic adversities. Over the years, they have unswervingly maintained their preeminent status in Europe's GDP rankings. Notably, France, Germany, and the United Kingdom have consistently reigned as paramount economic powerhouses.

# %% [markdown]
# ## Making your own question 05?

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **A possible question is**: How has the energy consumption pattern in European countries changed over the years?
#
# **Answering this question will** help us gain insights into the changes in energy usage trends in European countries, which could be essential for energy planning and policy-making, particularly in the context of climate change and environmental sustainability.
#
# **How we answer this question**: We will consider the average energy consumption of each type of European countries by year to analyze and make comments.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
# compute average energy consumption in Europe by year for each type of energy
avg_energy_df = cleaned_df.groupby('Year')[['Electric Power Consumption(kWH per capita)','Renewable Energy Consumption (%)', 'Fossil Fuel Consumption (%)']].mean()
avg_energy_df = avg_energy_df.reset_index().sort_values('Year', ascending=True)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# plot the average energy consumption in Europe by year for each type of energy by 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.lineplot(data=avg_energy_df, x='Year', y='Electric Power Consumption(kWH per capita)', marker='o', color='blue', label='Electric Power Consumption(kWH per capita)', ax=axes[0])
axes[0].set_title('Electric Power Consumption(kWH per capita) in Europe Over the Years')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Electric Power Consumption(kWH per capita)')
axes[0].grid(True)

sns.lineplot(data=avg_energy_df, x='Year', y='Renewable Energy Consumption (%)', marker='o', color='green', label='Renewable Energy Consumption (%)', ax=axes[1])
sns.lineplot(data=avg_energy_df, x='Year', y='Fossil Fuel Consumption (%)', marker='o', color='red', label='Fossil Fuel Consumption (%)', ax=axes[1])
axes[1].set_title('Renewable Energy Consumption (%) and Fossil Fuel Consumption (%) in Europe Over the Years')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Energy Consumption (%)')
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Electric Power Consumption (kWh per capita):
#   - From 1995 to 2005, electricity consumption per capita steadily increased.
#   - After 2008, there was minor fluctuation in electricity consumption, even a slight decrease from 2013 to 2016.
#   - From 2016 onwards, electricity consumption has remained relatively stable at around 6828.76 kWh per capita.
#
# - Renewable Energy Consumption (%): From 1990 to 2020, the percentage of renewable energy consumption gradually increased from approximately 12.6% to 26.34%.
#
# - Fossil Fuel Consumption (%):
#   - From 1985 to 2015, the percentage of fossil fuel consumption decreased from about 78.89% to 68.6%.
#   - From 2015 onwards, the percentage of fossil fuel consumption has remained relatively stable at 75.12%.
#
# The changes in energy usage trends can be explained by several factors, including:
#
# - Population growth and economic development: The European population has significantly increased in recent years, and economic development has led to an increased demand for energy for production, transportation, and consumption.
# - Development of renewable energy technology: The development of renewable energy technologies, such as solar and wind energy, has reduced costs and increased the efficiency of these energy sources, leading to greater adoption of renewable energy in Europe.
# - Concerns about climate change: Concerns about climate change have prompted European countries to shift towards cleaner energy sources, such as renewable energy.

# %% [markdown]
# ## Making your own question 06?

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **A possible question is**: How has the primary school enrollment rate and the tertiary school enrollment rate changed over the years in European countries?
#
# **Answering this question will** help we understanding the development of the primary and tertiary school enrollment rates in European countries and can provide insights into the future education landscape. This can help countries formulate appropriate education policies to ensure access to education for everyone.
#
# **How we answer this question**: We will analyze and comment on the average primary school enrollment rate and the average tertiary school enrollment rate of European countries by year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
# Compute average primary school enrollment and tertiary school enrollment in Europe by year
avg_school_df = cleaned_df.groupby('Year')[['School enrollment, primary','School enrollment, tertiary']].mean()
avg_school_df = avg_school_df.reset_index().sort_values('Year', ascending=True)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# plot the average primary school enrollment and tertiary school enrollment in Europe by year
plt.figure(figsize=(10, 5))
sns.lineplot(data=avg_school_df, x='Year', y='School enrollment, primary', marker='o', color='blue', label='School enrollment, primary')
sns.lineplot(data=avg_school_df, x='Year', y='School enrollment, tertiary', marker='o', color='green', label='School enrollment, tertiary')
plt.title('School Enrollment in Europe Over the Years')
plt.xlabel('Year')
plt.ylabel('School Enrollment')
plt.grid(True)
plt.show()

# %% [markdown]
# - Primary School Enrollment Rate: From 1985 to 2022, the primary school enrollment rate in European countries remained relatively stable, at around 100%.
#
# - Tertiary School Enrollment Rate: The tertiary school enrollment rate in European countries significantly increased from 31.38% in 1985 to 69.57% in 2020. However, this rate dropped to 51.71% in 2021, possibly due to the impact of the COVID-19 pandemic.
#
# - The increase in the tertiary school enrollment rate can be explained by several factors, including:
#
#   - Economic development: Economic growth has led to higher income for European citizens, allowing them to invest more in their children's education.
#   - High-skilled labor demand: The development of knowledge-based economies has created a growing demand for high-skilled labor, driving many individuals to pursue higher education.
#   - Policies promoting higher education: Many European countries have implemented policies to encourage higher education, such as subsidies and tax incentives. These policies have also contributed to the increase in university enrollment.

# %% [markdown]
# ## Making your own question 07?

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **A possible question is**: How have male and female life expectancies changed in European countries from 1985 to 2022, and are there any significant differences in the trends between genders?
#
# **Answering this question will** help us understand the evolution of life expectancies for both males and females in European countries over the years. It can provide insights into any gender-specific patterns or differences in longevity trends, which can be valuable for healthcare and social policy planning.
#
# **How we answer this question**: We will analyze and comment on the trends in male and female average life expectancies in European countries from 1985 to 2022, examining any notable changes and differences between the genders. This analysis can shed light on the overall health and well-being of the population in the region.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
avg_life_expectancy_df = cleaned_df.groupby('Year')[['Male life expectancy','Female life expectancy']].mean()
avg_life_expectancy_df = avg_life_expectancy_df.reset_index().sort_values('Year', ascending=True)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(10, 5))
sns.lineplot(data=avg_life_expectancy_df, x='Year', y='Male life expectancy', marker='o', color='skyblue', label='Male life expectancy')
sns.lineplot(data=avg_life_expectancy_df, x='Year', y='Female life expectancy', marker='o', color='pink', label='Female life expectancy')
plt.title('Life Expectancy in Europe Over the Years')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# %% [markdown]
# - Overall, it can be observed that the average life expectancy for both males and females has increased from 1985 to 2022. This can be attributed to advancements in science and technology, medical expertise, healthcare, improved living conditions, and various other factors.
#
# - Female life expectancy consistently surpasses that of males throughout the 1985-2022 period, highlighting the well-documented biological characteristic of women having a longer life expectancy compared to men.
#
# - However, the life expectancy of both genders experienced a significant decline from 2020 to 2022, likely due to the impact of the COVID-19 pandemic. This downturn underscores the substantial effect of the pandemic on overall life expectancy.

# %% [markdown]
# ## Making your own question 08?

# %% [markdown]
# **YOUR ANSWER HERE**
#
# A possible question is: What is the correlation between "GDP in USD" and other characteristics for the top 5 European countries with the highest GDP?
#
# Answering this question will provide insights into the relationship between GDP and various other features in the five European countries with the highest GDP. It can help us understand how economic wealth correlates with other aspects of a country's development.
#
# How we answer this question: We will analyze the data for the top 5 European countries with the highest GDP and examine the correlations between their GDP in USD and other relevant characteristics. This analysis will shed light on the interconnectedness of economic prosperity with various socio-economic factors in these countries.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# Plot correlation matrix between GDP and other features in top 5 countries with highest GDP
top_5_gdp_df = cleaned_df[cleaned_df['Country'].isin(top_5_gdp)]
top_5_gdp_df.drop(['Year', 'Country'], inplace=True, axis='columns')
fig, ax = plt.subplots(figsize=(7,7))
sns.heatmap(top_5_gdp_df.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **We will examine features with correlations of 0.6 or higher, indicating strong correlations.**
#
# Looking at the "GDP in USD" row (or column) of the top 5 European countries with the highest GDP, we can observe strong correlations with the following features:
# - **Total Population, Male Population, Female Population:** The strong correlation with population-related metrics suggests that larger populations might lead to higher GDP due to the availability of a larger labor force and consumer base.
# - **Compulsory Education Dur.:** A strong correlation here indicates that countries with longer compulsory education periods may have a more educated workforce, potentially contributing to economic growth.
# - **Employment in Agriculture(%), Female Employment in Agriculture(%):** The positive correlation with these variables suggests that countries with a significant agricultural sector may have higher GDP. Additionally, the correlation with female employment in agriculture highlights the role of women in this sector.
# - **Electric Power Consumption(kWH per capita):** A strong correlation with electricity consumption per capita signifies the importance of energy availability for economic activities and a higher standard of living.
