# %% [markdown]
# ## Connect to MongoDB using pymongo

# %%
# Install the pymongo package
# !pip install --upgrade "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (676 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 4.0 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.6.3

# %%
# Necessary packages and classes
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Required URI to connect to the databases, which must be given in advance
uri = "mongodb+srv://student:student@bigdata.zyjwsrz.mongodb.net/"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Get the data records in the collection 'users' of the database 'sample_mflix'
# These names must be given in advance
mongoData = client['sample_mflix']['users']
# Check whether the data is get successfully by having a look at the first record
for c in mongoData.find():
  print(c)
  break
# Out:
# {'_id': ObjectId('59b99db5cfa9a34dcd7885b8'), 'name': 'Jaime Lannister', 'email': 'nikolaj_coster-waldau@gameofthron.es', 'password': '$2b$12$6vz7wiwO.EI5Rilvq1zUc./9480gb1uPtXcahDxIadgyC3PS8XCUK'}

# %%
# Transfer the data to a pandas DF for easy manipulation
import pandas as pd
pdData = pd.DataFrame(list(mongoData.find()))
display(pdData)
# You may need to convert a pandas DF to a Spark DF for further use
# Out:
#                           _id                 name  \
# 0    59b99db5cfa9a34dcd7885b8      Jaime Lannister
# 1    59b99db4cfa9a34dcd7885b6            Ned Stark
# 2    59b99db5cfa9a34dcd7885b9        Catelyn Stark
# 3    59b99db6cfa9a34dcd7885ba     Cersei Lannister
# 4    59b99dbbcfa9a34dcd7885c4           Bran Stark
# ..                        ...                  ...
# 180  59b99dfccfa9a34dcd788650        Blake Sellers
# 181  59b99dfdcfa9a34dcd788652       Bradley Brooks
# 182  59b99dfecfa9a34dcd788654  Jonathon Mccullough
# 183  59b99e04cfa9a34dcd788661       Nichole Miller
# 184  59b99e04cfa9a34dcd788663     Nicholas Johnson
#
#                                      email  \
# 0     nikolaj_coster-waldau@gameofthron.es
# 1                 sean_bean@gameofthron.es
# 2          michelle_fairley@gameofthron.es
# 3               lena_headey@gameofthron.es
# 4    isaac_hempstead_wright@gameofthron.es
# ..                                     ...
# 180            blake_sellers@fakegmail.com
# 181           bradley_brooks@fakegmail.com
# 182      jonathon_mccullough@fakegmail.com
# 183           nichole_miller@fakegmail.com
# 184         nicholas_johnson@fakegmail.com
#
#                                               password preferences
# 0    $2b$12$6vz7wiwO.EI5Rilvq1zUc./9480gb1uPtXcahDx...         NaN
# 1    $2b$12$UREFwsRUoyF0CRqGNK0LzO0HM/jLhgUCNNIJ9RJ...         NaN
# 2    $2b$12$fiaTH5Sh1zKNFX2i/FTEreWGjxoJxvmV7XL.qlf...         NaN
# 3    $2b$12$FExjgr7CLhNCa.oUsB9seub8mqcHzkJCFZ8heMc...         NaN
# 4    $2b$12$Z7/ztVm8eWMDwTg.doS.UO7JbsbA9IbLomND1Vx...         NaN
# ..                                                 ...         ...
# 180  $2b$12$g2u20yqqpzbNipA6lfIoBO3Cs9jM7jsWBhDheF1...         NaN
# 181  $2b$12$YvZMPevRPXozhmujYwhFe.oTEHhdvHrJEviyXaX...         NaN
# 182  $2b$12$uZlaQmlnL501KsvPJSCJbO47tz9.8GB8Hl0Xu31...         NaN
# 183  $2b$12$RwG1XZMs3MT/kfdH0L2EWOrfUkOuDkMl./KT.xl...         NaN
# 184  $2b$12$hdzNySj4l/tZR4op5oQXb.FStH3u7ZHjmhhtrpQ...         NaN
#
# [185 rows x 5 columns]

# %% [markdown]
# ## Connect to MongoDB using PySpark connection

# %%
# install java
# !apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# install spark (change the version number if needed)
# !wget -q https://downloads.apache.org/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz
# unzip the spark file to the current folder
# !tar xf spark-3.5.1-bin-hadoop3.tgz
# set your spark folder to your system path environment.
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [812 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [23.8 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,739 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,369 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,077 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,228 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,019 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,307 kB]
# Get:18 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main Sources [2,268 kB]
# Get:19 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main amd64 Packages [1,164 kB]
# Get:20 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [27.8 kB]
# Get:21 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [44.7 kB]
# Get:22 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [66.2 kB]
# Fetched 15.4 MB in 5s (3,034 kB/s)
# Reading package lists... Done

# %%
# start pyspark
# !pip install findspark
import findspark
findspark.init()
# Out:
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %%
# Neccessary packages and classes
import pyspark
from pyspark.sql import SparkSession
# Create a new client and connect to the server
uri = "mongodb+srv://student:student@bigdata.zyjwsrz.mongodb.net/"
spark = SparkSession \
    .builder.master("local")\
    .appName("Connect to MongoDB Cloud")\
    .config("spark.mongodb.input.uri", uri)\
    .config("spark.mongodb.output.uri", uri)\
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1")\
    .getOrCreate()
  # spark.mongodb.input.uri, spark.mongodb.output.uri, and spark.jars.packages must be specified

# %%
df =  spark.read.format("com.mongodb.spark.sql.DefaultSource")\
    .option("uri",uri)\
    .option("database", "sample_mflix")\
    .option("collection", "users")\
    .load()
df.show()
# format and uri must be specified, uri must be the same as above
# Out:
# +--------------------+--------------------+----------------+--------------------+
# |                 _id|               email|            name|            password|
# +--------------------+--------------------+----------------+--------------------+
# |{59b99db5cfa9a34d...|nikolaj_coster-wa...| Jaime Lannister|$2b$12$6vz7wiwO.E...|
# |{59b99db4cfa9a34d...|sean_bean@gameoft...|       Ned Stark|$2b$12$UREFwsRUoy...|
# |{59b99db5cfa9a34d...|michelle_fairley@...|   Catelyn Stark|$2b$12$fiaTH5Sh1z...|
# |{59b99db6cfa9a34d...|lena_headey@gameo...|Cersei Lannister|$2b$12$FExjgr7CLh...|
# |{59b99dbbcfa9a34d...|isaac_hempstead_w...|      Bran Stark|$2b$12$Z7/ztVm8eW...|
# |{59b99dbfcfa9a34d...|carice_van_houten...|      Melisandre|$2b$12$ZdSvCDMwVL...|
# |{59b99dc2cfa9a34d...|oona_chaplin@game...|   Talisa Maegyr|$2b$12$B3DKrkTVNJ...|
# |{59b99dc3cfa9a34d...|joe_dempsie@gameo...|          Gendry|$2b$12$ctQymjuvXC...|
# |{59b99dc5cfa9a34d...|hannah_murray@gam...|           Gilly|$2b$12$s6/CDf3HFL...|
# |{59b99dc5cfa9a34d...|gwendoline_christ...|Brienne of Tarth|$2b$12$YjMZPFrj1q...|
# |{59b99dc5cfa9a34d...|iwan_rheon@gameof...|   Ramsay Bolton|$2b$12$a5CtSXflNA...|
# |{59b99dc6cfa9a34d...|indira_varma@game...|    Ellaria Sand|$2b$12$/sfLmn9Awe...|
# |{59b99dc7cfa9a34d...|nathalie_emmanuel...|       Missandei|$2b$12$wMY9mXJCiD...|
# |{59b99dc9cfa9a34d...|michael_mcelhatto...|    Roose Bolton|$2b$12$JWXzYGip0v...|
# |{59b99dcacfa9a34d...|jonathan_pryce@ga...|The High Sparrow|$2b$12$wWkC3fCEuI...|
# |{59b99dcbcfa9a34d...|kristian_nairn@ga...|           Hodor|$2b$12$hFkSycBpMD...|
# |{59b99dcecfa9a34d...|dominic_carter@ga...|     Janos Slynt|$2b$12$ssMaPHBLj9...|
# |{59b99dcfcfa9a34d...|ron_donachie@game...|   Rodrik Cassel|$2b$12$dIvO2KpkHk...|
# |{59b99dcfcfa9a34d...|donald_sumpter@ga...|   Maester Luwin|$2b$12$K9m5hh0Lh....|
# |{59b99dcfcfa9a34d...|amrita_acharia@ga...|            Irri|$2b$12$mTvd3eFqgf...|
# +--------------------+--------------------+----------------+--------------------+
# only showing top 20 rows
