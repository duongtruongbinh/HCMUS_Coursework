# %% [markdown]
# # Trực quan hóa dữ liệu với Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

import datetime as dt
import math

# %% [markdown]
# ## Mục tiêu của trực quan hóa dữ liệu

# %% [markdown]
# **Mục tiêu 1: Để giúp bạn hiểu rõ hơn về dữ liệu/kết quả của mình.**
# - Phần quan trọng trong khám phá dữ liệu (exploratory data)
# - Tóm tắc các xu hướng một cách trực quan trước khi phân tích sâu hơn
#
# **Mục tiêu 2: Truyền đạt kết quả/kết luận cho người khác.**
# - Tính chỉnh sửa và chọn lọc cao
# - Cần tinh chỉnh để đạt được mục tiêu truyền đạt.
#
# **Lưu ý**:
# - Visualizations aren't a matter of making "pretty" pictures.
# - We need to do a lot of thinking about what stylistic choices communicate ideas most effective

# %% [markdown]
# Trực quan hóa gồm hai giai đoạn:
# - Chọn đúng plot
# - Tình chỉnh plot phù hợp

# %% [markdown]
# ## Histogram
#
# Dùng để trực quan hóa phân bố các giá trị của biến dạng "numerical"
# - **Numerical**
# - Categorical
#
# Histogram gồm:
# - Phân chia các điểm dữ liệu có giá trị tương tự vào một "bin" chung.
# - Scale các bin sao cho diện tích của mỗi bin bằng tỷ lệ phần trăm của các điểm dữ liệu trong đó

# %% [markdown]
# ### Đọc dữ liệu điểm quiz từ file và tiền xử lý

# %%
# Đọc dữ liệu về kết quả làm quiz của lớp
# (Code lấy từ file 05-Demo.ipynb)
file = open('Data/PythonQuiz2023.csv', 'r',encoding='utf-8-sig')

cols = {}
first_line_vals = file.readline().rstrip().split(',')
for first_line_val in first_line_vals:
    cols[first_line_val] = []
for line in file:
    line_vals = line.rstrip().split(',')
    if (line_vals[0] == 'Never submitted'):
        continue
    for i in range(len(line_vals)):
        cols[first_line_vals[i]].append(line_vals[i])

file.close()

for col_name, col_vals in cols.items():
    print(f'{col_name}: [{col_vals[0]}, ...]')
# Out:
# State: [Finished, ...]
# Started on: [17/10/2023 18:00, ...]
# Completed: [17/10/2023 18:24, ...]
# Time taken: [24 mins 1 sec, ...]
# Grade/10.00: [9.53, ...]
# Q. 1 /0.63: [0.63, ...]
# Q. 2 /0.63: [0.63, ...]
# Q. 3 /0.63: [0.63, ...]
# Q. 4 /0.63: [0.63, ...]
# Q. 5 /0.63: [0.63, ...]
# Q. 6 /0.63: [0.63, ...]
# Q. 7 /0.63: [0.63, ...]
# Q. 8 /0.63: [0.63, ...]
# Q. 9 /0.63: [0.63, ...]
# Q. 10 /0.63: [0.47, ...]
# Q. 11 /0.63: [0.31, ...]
# Q. 12 /0.63: [0.63, ...]
# Q. 13 /0.63: [0.63, ...]
# Q. 14 /0.63: [0.63, ...]
# Q. 15 /0.63: [0.63, ...]
# Q. 16 /0.63: [0.63, ...]

# %%
# Chuyển kiểu dữ liệu của các cột từ str sang kiểu dữ liệu phù hợp
# (Code lấy từ file 04-Demo.ipynb)
new_cols = {}
for col_name, col_vals in cols.items():
    if '/' in col_name:
        new_col_vals = []
        for col_val in col_vals:
            try:
                col_val = float(col_val)
            except:
                col_val = 0
            new_col_vals.append(float(col_val))
        new_cols[col_name] = new_col_vals
    elif col_name in ['Started on', 'Completed']:
        new_col_vals = []
        for col_val in col_vals:
            new_col_val = dt.datetime.strptime(col_val,
                                               '%d/%m/%Y %H:%M')
            new_col_vals.append(new_col_val)
        new_cols[col_name] = new_col_vals
    elif col_name == 'Time taken':
        new_col_vals = []
        for col_val in col_vals:
            hour = 0; minute = 0; second = 0
            temp_list = col_val.split(' ')
            for temp_i in range(len(temp_list)):
                if 'hour' in temp_list[temp_i]:
                    hour = int(temp_list[temp_i - 1])
                elif 'min' in temp_list[temp_i]:
                    minute = int(temp_list[temp_i - 1])
                elif 'sec' in temp_list[temp_i]:
                    second = int(temp_list[temp_i - 1])
            new_col_val = hour * 60 + minute + second / 60
            new_col_vals.append(new_col_val)
        new_cols[col_name] = new_col_vals
    else:
        new_cols[col_name] = col_vals

# %%
cols = new_cols
for col_name, col_vals in cols.items():
    print(f'{col_name} {type(col_vals[0])}')
# Out:
# State <class 'str'>
# Started on <class 'datetime.datetime'>
# Completed <class 'datetime.datetime'>
# Time taken <class 'float'>
# Grade/10.00 <class 'float'>
# Q. 1 /0.63 <class 'float'>
# Q. 2 /0.63 <class 'float'>
# Q. 3 /0.63 <class 'float'>
# Q. 4 /0.63 <class 'float'>
# Q. 5 /0.63 <class 'float'>
# Q. 6 /0.63 <class 'float'>
# Q. 7 /0.63 <class 'float'>
# Q. 8 /0.63 <class 'float'>
# Q. 9 /0.63 <class 'float'>
# Q. 10 /0.63 <class 'float'>
# Q. 11 /0.63 <class 'float'>
# Q. 12 /0.63 <class 'float'>
# Q. 13 /0.63 <class 'float'>
# Q. 14 /0.63 <class 'float'>
# Q. 15 /0.63 <class 'float'>
# Q. 16 /0.63 <class 'float'>

# %% [markdown]
# ### Vẽ histogram của cột điểm "Grade/10.00" với 4 bin có độ rộng bằng nhau

# %%
hist = plt.hist(cols['Grade/10.00'],bins= [0,2,4,6,8,10],edgecolor='black');
print(hist)
plt.xlabel('Grade')
plt.ylabel('Num of students')
plt.title('Histogram of quiz grades')
# Out:
# (array([ 1.,  0., 10., 18., 26.]), array([ 0.,  2.,  4.,  6.,  8., 10.]), <BarContainer object of 5 artists>)
# Text(0.5, 1.0, 'Histogram of quiz grades')

# %% [markdown]
# Kết quả đã tính ở file "04-Demo.ipynb": \
# `{(0, 2): 0, (2, 4): 0, (4, 6): 10, (6, 8): 18, (8, 10): 26}`\
#     *Bộ dữ liệu hơn khác với bài 04-Demo.ipynb để minh họa thêm ý trong bài này*\
#     *Trong Dataset dùng trong bài 04-Demo.ipynb, (0, 2): 1*

# %%
# Chia ra 4 bin có độ rộng bằng nhau
# bằng cách truyền một con số vào tham số bin của plt.hist

hist = plt.hist(cols['Grade/10.00'],bins= 5,edgecolor='black');
print(hist)
plt.xlabel('Grade')
plt.ylabel('Num of students')
plt.title('Histogram of quiz grades')
plt.xticks(hist[1])
# Out:
# (array([ 1.,  0., 10., 18., 26.]), array([ 0.,  2.,  4.,  6.,  8., 10.]), <BarContainer object of 5 artists>)
# ([<matplotlib.axis.XTick at 0x7f5c4a54beb0>,
#   <matplotlib.axis.XTick at 0x7f5c4a54bd90>,
#   <matplotlib.axis.XTick at 0x7f5c4a54b850>,
#   <matplotlib.axis.XTick at 0x7f5c4a5bcd60>,
#   <matplotlib.axis.XTick at 0x7f5c4a5bd540>,
#   <matplotlib.axis.XTick at 0x7f5c4a5bdff0>],
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10')])

# %% [markdown]
# ### Vẽ histogram của cột điểm "Grade/10.00" với 2 bin có độ rộng không bằng nhau là [0, 7.5) và [7.5, 10]

# %%
hist = plt.hist(cols['Grade/10.00'],bins= [0,7.5,10],edgecolor='black');
print(hist)
plt.xlabel('Grade')
plt.ylabel('Num of students')
plt.title('Histogram of quiz grades')
# Out:
# (array([20., 35.]), array([ 0. ,  7.5, 10. ]), <BarContainer object of 2 artists>)
# Text(0.5, 1.0, 'Histogram of quiz grades')

# %% [markdown]
# Khi nhìn hình, bạn cảm nhận số lượng sinh viên ở bin thứ 1 như thế nào với bin thứ 2? \
# Có vẻ nhiều hơn!
#
# Nhưng cảm nhận này không đúng: bin thứ 1 có 19 sinh viên, còn bin thứ 2 có 35 sinh viên.
#
# Tại sao ta lại có cảm nhận không đúng này? \
# Vì mắt của ta tập trung vào diện tích của cột hơn là chiều cao của cột.
#
# Hình vẽ ở trên thật ra không phải là histogram!

# %%
# Đây mới là histogram!
# Diện tích của cột ứng với số lượng sinh viên đã được chuẩn hóa 
# về tỉ lệ tương đối (tổng diện tích của các cột sẽ bằng 1) 
hist = plt.hist(cols['Grade/10.00'],bins= [0,7.5,10],edgecolor='black',density=True);
print(hist)
plt.xlabel('Grade')
plt.ylabel('Density')
plt.title('Density (proportion per grade)')
# Out:
# (array([0.04848485, 0.25454545]), array([ 0. ,  7.5, 10. ]), <BarContainer object of 2 artists>)
# Text(0.5, 1.0, 'Density (proportion per grade)')

# %%
hist[0][0] * 7.5
# Out:
# 0.36363636363636365

# %%
hist[0][1] *2.5
# Out:
# 0.6363636363636362

# %% [markdown]
# ### Tiếp tục với histogram gồm 2 bin [0, 7.5) và [7.5, 10]: phân bố của các giá trị trong bin [7.5, 10]?

# %% [markdown]
# Histogram giả định các giá trị được phân bố đều trong mỗi bin. Điều này được thể hiện bởi đường nằm ngang ở trên đầu cột của mỗi bin.

# %%
# Thử chi tiết hóa ra bin [12, 16]
# Thử chi tiết hóa ra bin [12, 16]
hist = plt.hist(cols['Grade/10.00'], 
                [0, 7.5, 8, 8.5, 9, 9.5, 10], 
                edgecolor='black', density=True)
plt.xlabel('Grade')
plt.ylabel('Proportion per grade')
plt.title('Histogram of quiz grades')
plt.xticks(hist[1], rotation=90);

# %% [markdown]
# Tùy ngữ cảnh cụ thể mà bạn có thể muốn chi tiết hóa ra, có thể không muốn chi tiết hóa ra, nhưng khi nhìn hình của histogram thì bạn nên hiểu về giả định phân bố đều trong mỗi bin của histogram.

# %% [markdown]
# ### Vẽ histogram của cột điểm "Grade/10.00" với 4 bin [0, 2), [2, 4), [4, 6),  [6, 8), [8, 10] + 3 đường đứng ứng với lower quartile, median, upper quartile

# %%
def compute_percentile(data, p):
    sorted_grades = sorted(data)
    i = int(p/100 * (len(sorted_grades)-1))
    return sorted_grades[i]
lower_quartile = compute_percentile(cols['Grade/10.00'], 25)
median = compute_percentile(cols['Grade/10.00'], 50)
upper_quartile = compute_percentile(cols['Grade/10.00'], 75)
lower_quartile, median, upper_quartile
# Out:
# (6.25, 7.97, 9.38)

# %%
hist = plt.hist(cols['Grade/10.00'], [0, 2, 4, 6, 8,10], 
                edgecolor='black', density=True)
plt.xlabel('Grade')
plt.ylabel('Proportion per grade')
plt.title('Histogram of quiz grades')
plt.xticks(hist[1])
plt.axvline(lower_quartile, 
            color='red', linestyle='solid', linewidth=3, 
            label='lower quartile')
plt.axvline(median, 
            color='violet', linestyle='dashed', linewidth=3,
            label='median')
plt.axvline(upper_quartile, 
            color='yellow', linestyle='dotted', linewidth=3,
            label='upper quartile')
plt.legend();

# %% [markdown]
# Tại sao diện tích của cột từ upper quartile đến max lại không tương đương với từ median đến upper quartile?
#
# Do giả định phân bố đều của histogram trong bin [5, 10] là không chính xác. Thật ra là có nhiều giá trị tập trung vào vùng từ upper quartile đến max hơn là từ median đến upper quartile.

# %%
# So sánh histogram của các distribution
x1 = np.random.normal(0,0.8,1000)
x2 = np.random.normal(-2,1,1000)
x3 = np.random.normal(3,2,1000)
kwargs = dict(edgecolor='black',density=True,alpha =0.5,bins= 40,histtype='stepfilled')
plt.hist(x1,**kwargs)
plt.hist(x2,**kwargs)
plt.hist(x3,**kwargs)
# Out:
# (array([0.00316766, 0.        , 0.00316766, 0.00633532, 0.00316766,
#         0.02534127, 0.01900595, 0.02850892, 0.02217361, 0.05068253,
#         0.04117956, 0.05385019, 0.08552677, 0.10136507, 0.13937697,
#         0.13937697, 0.15521526, 0.1520476 , 0.17105355, 0.13937697,
#         0.20906545, 0.20906545, 0.18055652, 0.17105355, 0.17422121,
#         0.19956247, 0.12353867, 0.10770038, 0.12037102, 0.08552677,
#         0.08552677, 0.05068253, 0.0380119 , 0.02534127, 0.01267063,
#         0.00633532, 0.00950297, 0.00950297, 0.00316766, 0.00633532]),
#  array([-3.63411035, -3.31841974, -3.00272913, -2.68703851, -2.3713479 ,
#         -2.05565728, -1.73996667, -1.42427606, -1.10858544, -0.79289483,
#         -0.47720421, -0.1615136 ,  0.15417701,  0.46986763,  0.78555824,
#          1.10124886,  1.41693947,  1.73263008,  2.0483207 ,  2.36401131,
#          2.67970193,  2.99539254,  3.31108315,  3.62677377,  3.94246438,
#          4.258155  ,  4.57384561,  4.88953622,  5.20522684,  5.52091745,
#          5.83660807,  6.15229868,  6.46798929,  6.78367991,  7.09937052,
#          7.41506114,  7.73075175,  8.04644236,  8.36213298,  8.67782359,
#          8.99351421]),
#  [<matplotlib.patches.Polygon at 0x7f5c422230d0>])

# %%
## Two-Dimensional Histograms and Binnings
mean = [0,0]
cov = [[1,1],[1,2]]
x,y= np.random.multivariate_normal(mean,cov,10000).T

# %%
# Dùng plt.hist2d để vẽ 2D histogram
plt.hexbin(x,y,gridsize=20)
plt.xlabel('x')
plt.ylabel('y')
cb = plt.colorbar()
cb.set_label('Counts in bin')

# %% [markdown]
# ## Bar plot
#
# Dùng để trực quan hóa phân bố các giá trị của biến dạng "categorical"
# - Numerical
# - **Categorical**

# %% [markdown]
# ### Đọc dữ liệu đăng ký chuyên ngành K2021 (CQ) từ file và lấy ra cột các chuyên ngành

# %%
file = open('Data/CLC2021Majors.txt','r')
majors=[]
for line in file:
    if (line[0].isdigit()):
        words = line.strip().split(' ')
        major =''
        for i in range(len(words)-1,-1,-1):
            major = words[i]+' '+major
            if (words[i][0].isupper() and words[i-1][0].isupper()):
                break
        majors.append(major.strip())
file.close()
majors
# Out:
# ['Công nghệ tri thức',
#  'Công nghệ tri thức',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Thị giác máy tính',
#  'Hệ thống thông tin',
#  'Thị giác máy tính',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Thị giác máy tính',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Hệ thống thông tin',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học dữ liệu',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Thị giác máy tính',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Khoa học dữ liệu',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Thị giác máy tính',
#  'Công nghệ thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Thị giác máy tính',
#  'Thị giác máy tính',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Công nghệ tri thức',
#  'Thị giác máy tính',
#  'Công nghệ tri thức',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Thị giác máy tính',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Thị giác máy tính',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Công nghệ tri thức',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Khoa học dữ liệu',
#  'Khoa học dữ liệu',
#  'Thị giác máy tính',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Thị giác máy tính',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Thị giác máy tính',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Thị giác máy tính',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Công nghệ thông tin',
#  'Công nghệ tri thức',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Thị giác máy tính',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Công nghệ tri thức',
#  'Thị giác máy tính',
#  'Công nghệ tri thức',
#  'Công nghệ tri thức',
#  'Khoa học dữ liệu',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Thị giác máy tính',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Công nghệ tri thức',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Khoa học dữ liệu',
#  'Thị giác máy tính',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Hệ thống thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Công nghệ thông tin',
#  'Thị giác máy tính',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Khoa học dữ liệu',
#  'Thị giác máy tính',
#  'Hệ thống thông tin',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Thị giác máy tính',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Khoa học dữ liệu',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Hệ thống thông tin',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Công nghệ thông tin',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Công nghệ tri thức',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Khoa học máy tính hướng Trí tuệ nhân tạo',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Thị giác máy tính',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin',
#  'Hệ thống thông tin',
#  'Công nghệ thông tin',
#  'Công nghệ thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Hệ thống thông tin',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Khoa học dữ liệu',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Hệ thống thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Thị giác máy tính',
#  'Công nghệ tri thức',
#  'Kỹ thuật phần mềm',
#  'Công nghệ tri thức',
#  'Hệ thống thông tin',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Công nghệ thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Công nghệ tri thức',
#  'Mạng máy tính và Viễn thông hướng An toàn thông tin',
#  'Kỹ thuật phần mềm',
#  'Kỹ thuật phần mềm',
#  'Công nghệ thông tin',
#  'Công nghệ tri thức',
#  'Công nghệ thông tin',
#  'Khoa học dữ liệu',
#  'Kỹ thuật phần mềm',
#  'Thị giác máy tính',
#  'Công nghệ thông tin',
#  'Khoa học dữ liệu',
#  'Công nghệ thông tin']

# %% [markdown]
# ### Vẽ bar plot của cột các chuyên ngành

# %% [markdown]
# Bước 1: đếm số lần xuất hiện của mỗi chuyên ngành

# %%
majors_dist_df = pd.DataFrame({'Major':majors})
majors_dist = majors_dist_df['Major'].value_counts()
majors_dist
# Out:
# Kỹ thuật phần mềm                                      119
# Hệ thống thông tin                                      73
# Công nghệ thông tin                                     55
# Khoa học máy tính hướng Trí tuệ nhân tạo                42
# Khoa học dữ liệu                                        40
# Công nghệ tri thức                                      38
# Mạng máy tính và Viễn thông hướng An toàn thông tin     35
# Thị giác máy tính                                       34
# Name: Major, dtype: int64

# %%
majors = majors_dist.index
counts = majors_dist.values

# %% [markdown]
# Bước 2: vẽ bar plot từ kết quả của bước 1

# %%
plt.bar(majors, counts)
plt.ylabel('Số lượng SV')
plt.xticks(rotation=90);

# %%
plt.barh(majors, counts)
plt.xlabel('Số lượng SV');

# %%
# Trong bar plot, ta thường sẽ chuẩn hóa các giá trị đếm 
# về tỉ lệ tương đối
ratio = counts/np.sum(counts)
plt.barh(major,ratio)
plt.xlabel('Tỉ lệ Sinh Viên')
plt.xlim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# `pandas` native plotting:

# %%
majors_dist_df['Major'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Bar plot vs histogram?

# %% [markdown]
# Bar plot | Histogram
# :--- | :---
# Trục hoành (hay trục tung đối với bar plot nằm ngang) là biến "categorical" | Trục hoành là biến "numerical"
# Với biến "categorical" không có tính thứ tự (ví dụ, chuyên ngành) thì các bar không có thứ tự với nhau và ta có thể sắp xếp lại thứ tự của các bar cho dễ nhìn bằng cách sort các bar theo chiều cao; với biến "categorical" có tính thứ tự (ví dụ, mức độ hài lòng với các giá trị: rất hài lòng, hài lòng, không hài lòng, ...) thì các bar có thứ tự với nhau | Các bar có thứ tự với nhau
# Các bar có độ rộng bằng nhau, giữa các bar có thể có các khoảng không và các khoảng không này bằng nhau | Các bar có thể có độ rộng không bằng nhau, các bar nằm nối tiếp nhau tạo thành một đoạn liên tục trên trục hoành
# Tỉ lệ các phần tử tương ứng với chiều cao của bar | Tỉ lệ các phần tử tương ứng với diện tích của bar

# %% [markdown]
# ## Ôn lại các câu lệnh đã học

# %% [markdown]
# Câu lệnh | Ý nghĩa
# :--- | :---
# `plt.hist` | Vẽ histogram của biến dạng "numeric"
# `plt.bar`, `plt.barh` | Vẽ bar chart của biến dạng "categorical" (cần phải tính số lần hoặc tỉ lệ của các giá trị trước khi vẽ)
# `plt.title` | Thêm tựa đề cho hình vẽ
# `plt.xlabel` & `plt.ylabel` | Thêm nhãn cho trục x & y
# `plt.xlim` & `plt.ylim` | Giới hạn miền giá trị cho trục x & y
# `plt.xticks` & `plt.yticks` | Chỉ định các tick cho trục x & y
# `plt.axvline` & `plt.axhline` | Vẽ đường thẳng nằm đứng & nằm ngang
# `plt.legend` | Thêm chú thích cho ký hiệu, màu, ... trên hình vẽ
# `plt.savefig` | Lưu hình vẽ xuống file

# %% [markdown]
# ## Một số cách plot phổ biến khác

# %%
plt.boxplot(cols['Grade/10.00'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5c41df7c10>,
#   <matplotlib.lines.Line2D at 0x7f5c41df7eb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f5c41c30190>,
#   <matplotlib.lines.Line2D at 0x7f5c41c30430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5c41df7970>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f5c41c306d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5c41c30970>],
#  'means': []}

# %%
np.random.seed(10)
data = np.random.normal(100,20,200)
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5c41c76e00>,
#   <matplotlib.lines.Line2D at 0x7f5c41c77100>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f5c41c773a0>,
#   <matplotlib.lines.Line2D at 0x7f5c41c77640>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5c41c76d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f5c41c778e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5c41c77b80>],
#  'means': []}

# %%
plt.violinplot(data);

# %%
# Scatter Plots dùng để trực quan hóa mối quan hệ giữa hai biến liên tục
x =np.linspace(0,10,100)
y = np.sin(x)
plt.scatter(x,y,color='red');

# %%
rng = np.random.RandomState(0)
for mark in ['o','.','>','v','<','^','s','d','8']:
    plt.plot(rng.rand(5),rng.rand(5),mark,label=f'marker={mark}')
    plt.legend()

plt.xlim(0,1.5)
# Out:
# (0.0, 1.5)

# %%
plt.plot(x,y,'-o',color='green',markersize=10,lw=4,mfc='blue',mec='pink');

# %% [markdown]
# **Dùng scatter plot**

# %%
plt.scatter(x,y)

# %%
# Format của từng point (size, face color, edge color) có thể được xử lý riêng lẻ
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)

colors=rng.rand(100)
sizes = 100*rng.rand(100)

plt.scatter(x,y,c=colors,s=sizes,alpha =0.5,cmap='viridis');
plt.colorbar()

# %% [markdown]
# - `plot` sẽ nhanh hơn scatter (trên dữ liệu lớn)
# - `scatter` sẽ hiển thị được các điểm khác nhau.

# %% [markdown]
# ## Nói thêm về matplotlib

# %% [markdown]
# ### Ba cách dùng matplotlib

# %% [markdown]
# <font color=blue>Cách 1: Dùng các câu lệnh của `plt`</font> (trước giờ là làm theo cách này)

# %%
values = ['a', 'b', 'c']
counts = [1, 2, 3]
plt.bar(values,counts)
plt.title('Bar chart')
value2 =['d','e']
count2=[5,6]
plt.bar(value2,count2)
# Out:
# <BarContainer object of 2 artists>

# %%
value2 =['d','e']
count2=[5,6]
plt.bar(value2,count2)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# <font color=blue>Cách 2: Dùng trực tiếp các phương thức của đối tượng figure ở bên dưới</font>

# %%
values = ['a', 'b', 'c']
counts = [1, 2, 3]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(values,counts)
ax.set_title('Bar')
# Out:
# Text(0.5, 1.0, 'Bar')

# %%
fig.savefig('Bar2.jpg')

# %% [markdown]
# <font color=blue>Cách 3: Trộn lẫn giữa cách 1 và cách 2</font>

# %%
plt.bar(values,counts)
plt.title('Bar 3')
fig = plt.gcf()

# %% [markdown]
# ### Thay đổi style cho các hình vẽ

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-colorblind')
hist = plt.hist(cols['Grade/10.00'], [0, 2, 4, 6, 8,10], 
                edgecolor='black', density=True)
plt.xlabel('Grade')
plt.ylabel('Proportion per grade')
plt.title('Histogram of quiz grades')
plt.xticks(hist[1])
plt.axvline(lower_quartile, 
            color='red', linestyle='solid', linewidth=3, 
            label='lower quartile')
plt.axvline(median, 
            color='violet', linestyle='dashed', linewidth=3,
            label='median')
plt.axvline(upper_quartile, 
            color='yellow', linestyle='dotted', linewidth=3,
            label='upper quartile')
plt.legend();

# %% [markdown]
# Xem thêm về các style ở [document](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).

# %% [markdown]
# # Vẽ nhiều subplot

# %%
plt.style.use('seaborn-v0_8-white')

# %% [markdown]
# **Tự tạo ra các trục tọa độ (axis)**

# %%
plt.axes()
plt.axes([0.65,0.65,0.2,0.2])
# Out:
# <Axes: >

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0.5,1,0.5],ylim=(-1.2,1.2))
ax2=fig.add_axes([0,0,1,0.4],ylim=(-1.2,1.2))

x=np.linspace(0,10)
ax1.plot(x,np.sin(x))
ax2.plot(x,np.cos(x))

# %% [markdown]
# **Dùng subplot (lưu ý không `s`)**

# %%
plt.subplot(2,3,1)
plt.subplot(2,3,2)
plt.subplot(2,3,3)
plt.subplot(2,3,4)
plt.subplot(2,3,5)
plt.subplot(2,3,6)
# Out:
# <Axes: >

# %%
# Thay đổi khoảng cách giữa các subplot

# %% [markdown]
# ### ``plt.subplots``: Vẽ toàn bộ gird
# **Lưu ý có `s`**

# %%
fig,ax = plt.subplots(2,3,sharex='col',sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.5,0.5,'ABC')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'go', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='blue')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='red')
y_hist.invert_xaxis()
